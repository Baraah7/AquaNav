# %% [markdown]
# # Fish Recognition Model - EfficientNetB0 Version
#
# ## Why EfficientNetB0?
# 1. **Better architecture** - More reliable for transfer learning than MobileNetV3
# 2. **Proven track record** - Works well for image classification tasks
# 3. **Similar size** - ~5MB unquantized, similar to MobileNetV3
# 4. **Better feature learning** - More layers and better compound scaling
#
# ## Key Improvements:
# 1. **EfficientNetB0** instead of MobileNetV3Small
# 2. **Class weights** - Forces balanced learning across all 4 classes
# 3. **Better monitoring** - Tests model during training with raw images
# 4. **No quantization** - Keeps full float32 precision
# 5. **Proper preprocessing** - Consistent between training and inference
#
# ## Setup:
# 1. Download dataset from: https://www.kaggle.com/datasets/crowww/a-large-scale-fish-dataset
# 2. Extract to: C:\Users\s62ht\Downloads\Fish_Dataset
# 3. Install requirements: `pip install tensorflow numpy pillow scikit-learn`
# 4. Run all cells in order

# %%
# %pip install scikit-learn

# Import required libraries
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.applications import EfficientNetB0
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import os
import shutil
import random
from pathlib import Path
from PIL import Image
from sklearn.utils.class_weight import compute_class_weight

print(f"TensorFlow version: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\s62ht\appdata\roaming\python\python313\site-packages (1.8.0)
# Requirement already satisfied: numpy>=1.24.1 in c:\users\s62ht\appdata\roaming\python\python313\site-packages (from scikit-learn) (2.4.1)
# Requirement already satisfied: scipy>=1.10.0 in c:\users\s62ht\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.17.0)
# Requirement already satisfied: joblib>=1.3.0 in c:\users\s62ht\appdata\roaming\python\python313\site-packages (from scikit-learn) (1.5.3)
# Requirement already satisfied: threadpoolctl>=3.2.0 in c:\users\s62ht\appdata\roaming\python\python313\site-packages (from scikit-learn) (3.6.0)
# Note: you may need to restart the kernel to use updated packages.
# TensorFlow version: 2.20.0
# GPU Available: []

# %%
# Configuration
IMG_SIZE = 224
BATCH_SIZE = 32
EPOCHS = 30
FINETUNE_EPOCHS = 15
CLASSES = ['Gilt-Head Bream', 'Hourse Mackerel', 'Sea Bass', 'Shrimp']

# Dataset paths
DATASET_BASE = r'C:\Users\s62ht\Downloads\Fish_Dataset\Fish_Dataset\Fish_Dataset'
SOURCE_SEABASS = f'{DATASET_BASE}\\Sea Bass\\Sea Bass'
SOURCE_SHRIMP = f'{DATASET_BASE}\\Shrimp\\Shrimp'
SOURCE_GILTHEAD = f'{DATASET_BASE}\\Gilt-Head Bream\\Gilt-Head Bream'
SOURCE_HORSEMACKEREL = f'{DATASET_BASE}\\Hourse Mackerel\\Hourse Mackerel'

# Working directory
WORK_DIR = r'C:\Users\s62ht\Downloads\fish_model_efficientnet'
TRAIN_DIR = f'{WORK_DIR}\\train'
VAL_DIR = f'{WORK_DIR}\\validation'

os.makedirs(WORK_DIR, exist_ok=True)

print("Configuration complete")
print(f"Dataset path: {DATASET_BASE}")
print(f"Output path: {WORK_DIR}")
# Out:
# Configuration complete
# Dataset path: C:\Users\s62ht\Downloads\Fish_Dataset\Fish_Dataset\Fish_Dataset
# Output path: C:\Users\s62ht\Downloads\fish_model_efficientnet

# %%
# Verify dataset exists
print("Checking dataset availability...")
for source, name in [
    (SOURCE_SEABASS, 'Sea Bass'),
    (SOURCE_SHRIMP, 'Shrimp'),
    (SOURCE_GILTHEAD, 'Gilt-Head Bream'),
    (SOURCE_HORSEMACKEREL, 'Hourse Mackerel')
]:
    if os.path.exists(source):
        count = len(os.listdir(source))
        print(f"✓ {name} images found: {count}")
    else:
        print(f"✗ {name} folder not found at {source}")
# Out:
# Checking dataset availability...
# ✓ Sea Bass images found: 1000
# ✓ Shrimp images found: 1000
# ✓ Gilt-Head Bream images found: 1000
# ✓ Hourse Mackerel images found: 1000

# %%
# Create train/validation split (80/20)
def split_dataset(source_dir, class_name, train_ratio=0.8):
    """Split dataset into train and validation sets"""
    if not os.path.exists(source_dir):
        print(f"✗ Error: Source directory not found: {source_dir}")
        return 0, 0
    
    # Create directories
    train_class_dir = os.path.join(TRAIN_DIR, class_name)
    val_class_dir = os.path.join(VAL_DIR, class_name)
    os.makedirs(train_class_dir, exist_ok=True)
    os.makedirs(val_class_dir, exist_ok=True)
    
    # Get all image files
    all_files = [f for f in os.listdir(source_dir) 
                 if f.lower().endswith(('.png', '.jpg', '.jpeg'))]
    
    if not all_files:
        print(f"✗ Warning: No image files found in {source_dir}")
        return 0, 0
    
    # Shuffle and split
    random.seed(42)
    random.shuffle(all_files)
    split_idx = int(len(all_files) * train_ratio)
    
    train_files = all_files[:split_idx]
    val_files = all_files[split_idx:]
    
    # Copy files
    for filename in train_files:
        src = os.path.join(source_dir, filename)
        dst = os.path.join(train_class_dir, filename)
        shutil.copy2(src, dst)
    
    for filename in val_files:
        src = os.path.join(source_dir, filename)
        dst = os.path.join(val_class_dir, filename)
        shutil.copy2(src, dst)
    
    print(f"✓ {class_name}: {len(train_files)} train, {len(val_files)} validation")
    return len(train_files), len(val_files)

print("Splitting dataset...")
split_dataset(SOURCE_GILTHEAD, 'Gilt-Head Bream')
split_dataset(SOURCE_HORSEMACKEREL, 'Hourse Mackerel')
split_dataset(SOURCE_SEABASS, 'Sea Bass')
split_dataset(SOURCE_SHRIMP, 'Shrimp')
print("Dataset split complete!")
# Out:
# Splitting dataset...
# ✓ Gilt-Head Bream: 800 train, 200 validation
# ✓ Hourse Mackerel: 800 train, 200 validation
# ✓ Sea Bass: 800 train, 200 validation
# ✓ Shrimp: 800 train, 200 validation
# Dataset split complete!

# %%
# Custom preprocessing function that matches Flutter exactly
# This is CRITICAL - must be exactly (pixel / 127.5) - 1.0
def preprocess_for_efficientnet(x):
    """Preprocess image to [-1, 1] range"""
    # x is in range [0, 255]
    return (x / 127.5) - 1.0

# Create data generators with strong augmentation
train_datagen = ImageDataGenerator(
    preprocessing_function=preprocess_for_efficientnet,
    rotation_range=30,
    width_shift_range=0.25,
    height_shift_range=0.25,
    shear_range=0.25,
    zoom_range=0.25,
    horizontal_flip=True,
    fill_mode='nearest'
)

val_datagen = ImageDataGenerator(preprocessing_function=preprocess_for_efficientnet)

train_generator = train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=True,
    seed=42
)

validation_generator = val_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(IMG_SIZE, IMG_SIZE),
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False,
    seed=42
)

print(f"\nClass indices: {train_generator.class_indices}")
print(f"Total training samples: {train_generator.samples}")
print(f"Total validation samples: {validation_generator.samples}")
# Out:
# Found 3200 images belonging to 4 classes.
# Found 800 images belonging to 4 classes.
#
# Class indices: {'Gilt-Head Bream': 0, 'Hourse Mackerel': 1, 'Sea Bass': 2, 'Shrimp': 3}
# Total training samples: 3200
# Total validation samples: 800

# %%
# Calculate class weights to handle any imbalance
# This forces the model to pay equal attention to all classes
class_indices = train_generator.class_indices
class_labels = train_generator.classes

class_weights = compute_class_weight(
    class_weight='balanced',
    classes=np.unique(class_labels),
    y=class_labels
)
class_weight_dict = dict(enumerate(class_weights))

print("\nClass weights (to ensure balanced learning):")
for class_name, class_idx in sorted(class_indices.items(), key=lambda x: x[1]):
    print(f"  {class_name}: {class_weight_dict[class_idx]:.3f}")
# Out:
# Class weights (to ensure balanced learning):
#   Gilt-Head Bream: 1.000
#   Hourse Mackerel: 1.000
#   Sea Bass: 1.000
#   Shrimp: 1.000

# %%
# Build model with EfficientNetB0
def create_model():
    # Load pre-trained EfficientNetB0 (without top layers)
    base_model = EfficientNetB0(
        input_shape=(IMG_SIZE, IMG_SIZE, 3),
        include_top=False,
        weights='imagenet'
    )
    
    # Freeze base model initially
    base_model.trainable = False
    
    # Build classification head with strong regularization
    inputs = keras.Input(shape=(IMG_SIZE, IMG_SIZE, 3))
    x = base_model(inputs, training=False)
    x = layers.GlobalAveragePooling2D()(x)
    
    # Three-layer classifier for better feature learning
    x = layers.Dense(512, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.5)(x)
    
    x = layers.Dense(256, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.4)(x)
    
    x = layers.Dense(128, activation='relu', kernel_regularizer=keras.regularizers.l2(0.001))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Dropout(0.3)(x)
    
    # Output layer
    outputs = layers.Dense(len(CLASSES), activation='softmax')(x)
    
    model = keras.Model(inputs, outputs)
    return model, base_model

model, base_model = create_model()

# Compile with label smoothing
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.0005),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

print("Model created successfully")
print(f"Total parameters: {model.count_params():,}")
model.summary()
# Out:
# Downloading data from https://storage.googleapis.com/keras-applications/efficientnetb0_notop.h5
# 16705208/16705208 ━━━━━━━━━━━━━━━━━━━━ 9s 1us/step
# Model created successfully
# Total parameters: 4,873,767
# Model: "functional"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_1 (InputLayer)      │ (None, 224, 224, 3)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ efficientnetb0 (Functional)     │ (None, 7, 7, 1280)     │     4,049,571 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ global_average_pooling2d        │ (None, 1280)           │             0 │
# │ (GlobalAveragePooling2D)        │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │       655,872 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 512)            │         2,048 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 256)            │       131,328 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 256)            │         1,024 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 256)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 128)            │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 4)              │           516 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 4,873,767 (18.59 MB)
#  Trainable params: 822,404 (3.14 MB)
#  Non-trainable params: 4,051,363 (15.45 MB)

# %%
# Helper function to test model with raw images during training
def test_model_with_raw_images(model, labels, num_per_class=3):
    """Test model with raw images exactly like Flutter does"""
    
    def preprocess_image_flutter_style(image_path):
        """Preprocess image exactly as Flutter does"""
        img = Image.open(image_path).convert('RGB')
        
        # Center crop to square
        width, height = img.size
        size = min(width, height)
        left = (width - size) // 2
        top = (height - size) // 2
        img = img.crop((left, top, left + size, top + size))
        
        # Resize to 224x224
        img = img.resize((224, 224), Image.BILINEAR)
        
        # Normalize: (pixel / 127.5) - 1.0
        img_array = np.array(img, dtype=np.float32)
        img_array = (img_array / 127.5) - 1.0
        img_array = np.expand_dims(img_array, axis=0)
        
        return img_array
    
    total_correct = 0
    total_tested = 0
    
    print("\n" + "="*60)
    print("Testing model with raw images...")
    print("="*60)
    
    for class_name in labels:
        class_dir = os.path.join(VAL_DIR, class_name)
        if not os.path.exists(class_dir):
            continue
        
        images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))][:num_per_class]
        
        print(f"\n{class_name}:")
        class_correct = 0
        
        for img_name in images:
            img_path = os.path.join(class_dir, img_name)
            input_data = preprocess_image_flutter_style(img_path)
            
            # Run inference
            output = model.predict(input_data, verbose=0)[0]
            
            predicted_idx = np.argmax(output)
            predicted_label = labels[predicted_idx]
            confidence = output[predicted_idx]
            
            is_correct = predicted_label == class_name
            status = "✓" if is_correct else "✗"
            
            # Show probabilities
            probs_str = ", ".join([f"{labels[i]}: {output[i]*100:.1f}%" for i in range(len(labels))])
            print(f"  {status} {predicted_label} ({confidence*100:.1f}%) [{probs_str}]")
            
            if is_correct:
                class_correct += 1
                total_correct += 1
            total_tested += 1
        
        print(f"  Class accuracy: {class_correct}/{len(images)} = {class_correct/len(images)*100:.1f}%")
    
    accuracy = total_correct / total_tested if total_tested > 0 else 0
    print("\n" + "="*60)
    print(f"OVERALL RAW IMAGE ACCURACY: {total_correct}/{total_tested} = {accuracy*100:.1f}%")
    print("="*60 + "\n")
    
    return accuracy

print("Helper function defined")
# Out:
# Helper function defined

# %%
# Custom callback to test with raw images every 5 epochs
class RawImageTestCallback(keras.callbacks.Callback):
    def __init__(self, labels, test_frequency=5):
        super().__init__()
        self.labels = labels
        self.test_frequency = test_frequency
    
    def on_epoch_end(self, epoch, logs=None):
        if (epoch + 1) % self.test_frequency == 0:
            test_model_with_raw_images(self.model, self.labels, num_per_class=3)

# Training callbacks
callbacks = [
    keras.callbacks.EarlyStopping(
        monitor='val_loss',
        patience=8,
        restore_best_weights=True,
        verbose=1
    ),
    keras.callbacks.ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=4,
        min_lr=1e-7,
        verbose=1
    ),
    keras.callbacks.ModelCheckpoint(
        f'{WORK_DIR}/best_model.keras',
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    ),
    RawImageTestCallback(CLASSES, test_frequency=5)
]

print("Callbacks configured")
# Out:
# Callbacks configured

# %%
# PHASE 1: Train classifier head with class weights
print("="*60)
print("PHASE 1: Training classifier head")
print("="*60)

history = model.fit(
    train_generator,
    epochs=EPOCHS,
    validation_data=validation_generator,
    callbacks=callbacks,
    class_weight=class_weight_dict,  # Force balanced learning
    verbose=1
)

print("\nPhase 1 training complete!")
# Out:
# ============================================================
# PHASE 1: Training classifier head
# ============================================================
# Epoch 1/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.2590 - loss: 3.0728
# Epoch 1: val_accuracy improved from None to 0.25000, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 1: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 183s 2s/step - accuracy: 0.2625 - loss: 2.9301 - val_accuracy: 0.2500 - val_loss: 2.3224 - learning_rate: 5.0000e-04
# Epoch 2/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 860ms/step - accuracy: 0.2741 - loss: 2.6820
# Epoch 2: val_accuracy improved from 0.25000 to 0.25500, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 2: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 101s 1s/step - accuracy: 0.2700 - loss: 2.6390 - val_accuracy: 0.2550 - val_loss: 2.2725 - learning_rate: 5.0000e-04
# Epoch 3/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 844ms/step - accuracy: 0.2664 - loss: 2.5443
# Epoch 3: val_accuracy improved from 0.25500 to 0.26000, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 3: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 99s 989ms/step - accuracy: 0.2697 - loss: 2.5090 - val_accuracy: 0.2600 - val_loss: 2.2189 - learning_rate: 5.0000e-04
# Epoch 4/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 793ms/step - accuracy: 0.2786 - loss: 2.4214
# Epoch 4: val_accuracy improved from 0.26000 to 0.26125, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 4: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 94s 945ms/step - accuracy: 0.2759 - loss: 2.4046 - val_accuracy: 0.2612 - val_loss: 2.2470 - learning_rate: 5.0000e-04
# Epoch 5/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 854ms/step - accuracy: 0.2558 - loss: 2.3839
# Epoch 5: val_accuracy did not improve from 0.26125
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Sea Bass (43.7%) [Gilt-Head Bream: 19.0%, Hourse Mackerel: 16.6%, Sea Bass: 43.7%, Shrimp: 20.8%]
#   ✗ Sea Bass (44.2%) [Gilt-Head Bream: 18.8%, Hourse Mackerel: 17.2%, Sea Bass: 44.2%, Shrimp: 19.9%]
#   ✗ Sea Bass (44.2%) [Gilt-Head Bream: 18.8%, Hourse Mackerel: 17.1%, Sea Bass: 44.2%, Shrimp: 19.9%]
#   Class accuracy: 0/3 = 0.0%
#
# Hourse Mackerel:
#   ✗ Sea Bass (42.6%) [Gilt-Head Bream: 18.7%, Hourse Mackerel: 17.0%, Sea Bass: 42.6%, Shrimp: 21.7%]
#   ✗ Sea Bass (42.9%) [Gilt-Head Bream: 18.5%, Hourse Mackerel: 17.1%, Sea Bass: 42.9%, Shrimp: 21.5%]
#   ✗ Sea Bass (42.6%) [Gilt-Head Bream: 18.7%, Hourse Mackerel: 17.0%, Sea Bass: 42.6%, Shrimp: 21.7%]
#   Class accuracy: 0/3 = 0.0%
#
# Sea Bass:
#   ✓ Sea Bass (42.8%) [Gilt-Head Bream: 18.8%, Hourse Mackerel: 16.6%, Sea Bass: 42.8%, Shrimp: 21.8%]
#   ✓ Sea Bass (42.8%) [Gilt-Head Bream: 18.5%, Hourse Mackerel: 17.0%, Sea Bass: 42.8%, Shrimp: 21.6%]
#   ✓ Sea Bass (41.5%) [Gilt-Head Bream: 18.7%, Hourse Mackerel: 16.9%, Sea Bass: 41.5%, Shrimp: 22.8%]
#   Class accuracy: 3/3 = 100.0%
#
# Shrimp:
#   ✗ Sea Bass (41.7%) [Gilt-Head Bream: 19.0%, Hourse Mackerel: 16.4%, Sea Bass: 41.7%, Shrimp: 22.9%]
#   ✗ Sea Bass (41.0%) [Gilt-Head Bream: 18.9%, Hourse Mackerel: 16.6%, Sea Bass: 41.0%, Shrimp: 23.5%]
#   ✗ Sea Bass (42.4%) [Gilt-Head Bream: 18.7%, Hourse Mackerel: 16.5%, Sea Bass: 42.4%, Shrimp: 22.4%]
#   Class accuracy: 0/3 = 0.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 3/12 = 25.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.2663 - loss: 2.3544 - val_accuracy: 0.2500 - val_loss: 2.2075 - learning_rate: 5.0000e-04
# Epoch 6/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 870ms/step - accuracy: 0.2802 - loss: 2.2878
# Epoch 6: val_accuracy did not improve from 0.26125
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 100s 1s/step - accuracy: 0.2887 - loss: 2.2590 - val_accuracy: 0.2575 - val_loss: 2.0910 - learning_rate: 5.0000e-04
# Epoch 7/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 751ms/step - accuracy: 0.2844 - loss: 2.2221
# Epoch 7: val_accuracy improved from 0.26125 to 0.28875, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 7: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 89s 890ms/step - accuracy: 0.2884 - loss: 2.2036 - val_accuracy: 0.2887 - val_loss: 2.0900 - learning_rate: 5.0000e-04
# Epoch 8/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 775ms/step - accuracy: 0.3145 - loss: 2.1349
# Epoch 8: val_accuracy improved from 0.28875 to 0.41875, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 8: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 92s 919ms/step - accuracy: 0.3013 - loss: 2.1395 - val_accuracy: 0.4187 - val_loss: 2.0146 - learning_rate: 5.0000e-04
# Epoch 9/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 627ms/step - accuracy: 0.2964 - loss: 2.1137
# Epoch 9: val_accuracy did not improve from 0.41875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 123s 729ms/step - accuracy: 0.2988 - loss: 2.1023 - val_accuracy: 0.2500 - val_loss: 2.0346 - learning_rate: 5.0000e-04
# Epoch 10/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 683ms/step - accuracy: 0.3027 - loss: 2.0780
# Epoch 10: val_accuracy did not improve from 0.41875
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Sea Bass (30.2%) [Gilt-Head Bream: 29.3%, Hourse Mackerel: 23.4%, Sea Bass: 30.2%, Shrimp: 17.1%]
#   ✗ Sea Bass (31.4%) [Gilt-Head Bream: 31.1%, Hourse Mackerel: 23.9%, Sea Bass: 31.4%, Shrimp: 13.6%]
#   ✗ Sea Bass (31.7%) [Gilt-Head Bream: 31.0%, Hourse Mackerel: 24.0%, Sea Bass: 31.7%, Shrimp: 13.2%]
#   Class accuracy: 0/3 = 0.0%
#
# Hourse Mackerel:
#   ✗ Sea Bass (29.5%) [Gilt-Head Bream: 29.4%, Hourse Mackerel: 23.5%, Sea Bass: 29.5%, Shrimp: 17.6%]
#   ✗ Sea Bass (29.8%) [Gilt-Head Bream: 29.4%, Hourse Mackerel: 23.7%, Sea Bass: 29.8%, Shrimp: 17.0%]
#   ✗ Sea Bass (29.5%) [Gilt-Head Bream: 29.4%, Hourse Mackerel: 23.5%, Sea Bass: 29.5%, Shrimp: 17.6%]
#   Class accuracy: 0/3 = 0.0%
#
# Sea Bass:
#   ✓ Sea Bass (29.3%) [Gilt-Head Bream: 28.6%, Hourse Mackerel: 23.0%, Sea Bass: 29.3%, Shrimp: 19.1%]
#   ✗ Gilt-Head Bream (29.3%) [Gilt-Head Bream: 29.3%, Hourse Mackerel: 23.7%, Sea Bass: 29.3%, Shrimp: 17.7%]
#   ✓ Sea Bass (28.6%) [Gilt-Head Bream: 28.5%, Hourse Mackerel: 23.5%, Sea Bass: 28.6%, Shrimp: 19.4%]
#   Class accuracy: 2/3 = 66.7%
#
# Shrimp:
#   ✗ Sea Bass (28.6%) [Gilt-Head Bream: 27.7%, Hourse Mackerel: 22.4%, Sea Bass: 28.6%, Shrimp: 21.4%]
#   ✗ Sea Bass (28.3%) [Gilt-Head Bream: 27.7%, Hourse Mackerel: 22.6%, Sea Bass: 28.3%, Shrimp: 21.3%]
#   ✗ Sea Bass (28.9%) [Gilt-Head Bream: 28.2%, Hourse Mackerel: 22.6%, Sea Bass: 28.9%, Shrimp: 20.3%]
#   Class accuracy: 0/3 = 0.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 2/12 = 16.7%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 81s 816ms/step - accuracy: 0.3141 - loss: 2.0573 - val_accuracy: 0.2575 - val_loss: 1.9678 - learning_rate: 5.0000e-04
# Epoch 11/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 727ms/step - accuracy: 0.3125 - loss: 2.0280
# Epoch 11: val_accuracy did not improve from 0.41875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 85s 850ms/step - accuracy: 0.3197 - loss: 2.0113 - val_accuracy: 0.2825 - val_loss: 1.9637 - learning_rate: 5.0000e-04
# Epoch 12/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 712ms/step - accuracy: 0.3273 - loss: 1.9822
# Epoch 12: val_accuracy did not improve from 0.41875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 84s 840ms/step - accuracy: 0.3200 - loss: 1.9708 - val_accuracy: 0.2562 - val_loss: 1.8969 - learning_rate: 5.0000e-04
# Epoch 13/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 738ms/step - accuracy: 0.3194 - loss: 1.9534
# Epoch 13: val_accuracy improved from 0.41875 to 0.43625, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 13: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 90s 897ms/step - accuracy: 0.3241 - loss: 1.9395 - val_accuracy: 0.4363 - val_loss: 1.8255 - learning_rate: 5.0000e-04
# Epoch 14/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3397 - loss: 1.8941
# Epoch 14: val_accuracy did not improve from 0.43625
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 144s 1s/step - accuracy: 0.3413 - loss: 1.8845 - val_accuracy: 0.3400 - val_loss: 1.8417 - learning_rate: 5.0000e-04
# Epoch 15/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3383 - loss: 1.8648
# Epoch 15: val_accuracy improved from 0.43625 to 0.48875, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 15: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✓ Gilt-Head Bream (26.5%) [Gilt-Head Bream: 26.5%, Hourse Mackerel: 26.3%, Sea Bass: 23.5%, Shrimp: 23.7%]
#   ✗ Hourse Mackerel (28.8%) [Gilt-Head Bream: 26.6%, Hourse Mackerel: 28.8%, Sea Bass: 26.1%, Shrimp: 18.6%]
#   ✗ Hourse Mackerel (29.1%) [Gilt-Head Bream: 26.5%, Hourse Mackerel: 29.1%, Sea Bass: 26.8%, Shrimp: 17.6%]
#   Class accuracy: 1/3 = 33.3%
#
# Hourse Mackerel:
#   ✓ Hourse Mackerel (26.1%) [Gilt-Head Bream: 25.9%, Hourse Mackerel: 26.1%, Sea Bass: 22.1%, Shrimp: 25.8%]
#   ✓ Hourse Mackerel (26.5%) [Gilt-Head Bream: 26.0%, Hourse Mackerel: 26.5%, Sea Bass: 22.6%, Shrimp: 24.8%]
#   ✓ Hourse Mackerel (26.1%) [Gilt-Head Bream: 25.9%, Hourse Mackerel: 26.1%, Sea Bass: 22.1%, Shrimp: 25.8%]
#   Class accuracy: 3/3 = 100.0%
#
# Sea Bass:
#   ✗ Shrimp (28.4%) [Gilt-Head Bream: 25.9%, Hourse Mackerel: 24.6%, Sea Bass: 21.1%, Shrimp: 28.4%]
#   ✗ Gilt-Head Bream (26.3%) [Gilt-Head Bream: 26.3%, Hourse Mackerel: 25.8%, Sea Bass: 22.2%, Shrimp: 25.8%]
#   ✗ Shrimp (28.5%) [Gilt-Head Bream: 25.8%, Hourse Mackerel: 24.6%, Sea Bass: 21.1%, Shrimp: 28.5%]
#   Class accuracy: 0/3 = 0.0%
#
# Shrimp:
#   ✓ Shrimp (32.8%) [Gilt-Head Bream: 25.0%, Hourse Mackerel: 22.8%, Sea Bass: 19.5%, Shrimp: 32.8%]
#   ✓ Shrimp (33.0%) [Gilt-Head Bream: 24.9%, Hourse Mackerel: 22.6%, Sea Bass: 19.5%, Shrimp: 33.0%]
#   ✓ Shrimp (31.9%) [Gilt-Head Bream: 25.0%, Hourse Mackerel: 23.3%, Sea Bass: 19.8%, Shrimp: 31.9%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 7/12 = 58.3%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.3363 - loss: 1.8618 - val_accuracy: 0.4888 - val_loss: 1.7691 - learning_rate: 5.0000e-04
# Epoch 16/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3437 - loss: 1.8374
# Epoch 16: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.3419 - loss: 1.8267 - val_accuracy: 0.2500 - val_loss: 2.8480 - learning_rate: 5.0000e-04
# Epoch 17/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3609 - loss: 1.7985
# Epoch 17: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 166s 2s/step - accuracy: 0.3622 - loss: 1.7899 - val_accuracy: 0.2500 - val_loss: 2.8713 - learning_rate: 5.0000e-04
# Epoch 18/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3384 - loss: 1.7885
# Epoch 18: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.3425 - loss: 1.7754 - val_accuracy: 0.2675 - val_loss: 1.8875 - learning_rate: 5.0000e-04
# Epoch 19/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3825 - loss: 1.7385
# Epoch 19: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 19: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 165s 2s/step - accuracy: 0.3803 - loss: 1.7336 - val_accuracy: 0.2512 - val_loss: 1.7920 - learning_rate: 5.0000e-04
# Epoch 20/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3746 - loss: 1.7098
# Epoch 20: val_accuracy did not improve from 0.48875
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Shrimp (53.6%) [Gilt-Head Bream: 13.1%, Hourse Mackerel: 18.7%, Sea Bass: 14.7%, Shrimp: 53.6%]
#   ✗ Shrimp (48.2%) [Gilt-Head Bream: 14.8%, Hourse Mackerel: 20.9%, Sea Bass: 16.2%, Shrimp: 48.2%]
#   ✗ Shrimp (46.6%) [Gilt-Head Bream: 15.3%, Hourse Mackerel: 21.5%, Sea Bass: 16.7%, Shrimp: 46.6%]
#   Class accuracy: 0/3 = 0.0%
#
# Hourse Mackerel:
#   ✗ Shrimp (53.9%) [Gilt-Head Bream: 12.9%, Hourse Mackerel: 18.7%, Sea Bass: 14.5%, Shrimp: 53.9%]
#   ✗ Shrimp (53.1%) [Gilt-Head Bream: 13.1%, Hourse Mackerel: 19.1%, Sea Bass: 14.7%, Shrimp: 53.1%]
#   ✗ Shrimp (53.9%) [Gilt-Head Bream: 12.9%, Hourse Mackerel: 18.7%, Sea Bass: 14.5%, Shrimp: 53.9%]
#   Class accuracy: 0/3 = 0.0%
#
# Sea Bass:
#   ✗ Shrimp (56.6%) [Gilt-Head Bream: 12.1%, Hourse Mackerel: 17.5%, Sea Bass: 13.8%, Shrimp: 56.6%]
#   ✗ Shrimp (54.4%) [Gilt-Head Bream: 12.8%, Hourse Mackerel: 18.5%, Sea Bass: 14.4%, Shrimp: 54.4%]
#   ✗ Shrimp (55.9%) [Gilt-Head Bream: 12.4%, Hourse Mackerel: 17.7%, Sea Bass: 14.0%, Shrimp: 55.9%]
#   Class accuracy: 0/3 = 0.0%
#
# Shrimp:
#   ✓ Shrimp (59.9%) [Gilt-Head Bream: 11.3%, Hourse Mackerel: 16.1%, Sea Bass: 12.7%, Shrimp: 59.9%]
#   ✓ Shrimp (60.2%) [Gilt-Head Bream: 11.2%, Hourse Mackerel: 15.9%, Sea Bass: 12.7%, Shrimp: 60.2%]
#   ✓ Shrimp (59.3%) [Gilt-Head Bream: 11.4%, Hourse Mackerel: 16.4%, Sea Bass: 12.9%, Shrimp: 59.3%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 3/12 = 25.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.3716 - loss: 1.7153 - val_accuracy: 0.2663 - val_loss: 1.7825 - learning_rate: 2.5000e-04
# Epoch 21/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3432 - loss: 1.7030
# Epoch 21: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 167s 2s/step - accuracy: 0.3666 - loss: 1.6916 - val_accuracy: 0.3050 - val_loss: 1.7261 - learning_rate: 2.5000e-04
# Epoch 22/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3805 - loss: 1.6855
# Epoch 22: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 169s 2s/step - accuracy: 0.3872 - loss: 1.6767 - val_accuracy: 0.2988 - val_loss: 1.8652 - learning_rate: 2.5000e-04
# Epoch 23/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3649 - loss: 1.6640
# Epoch 23: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 179s 2s/step - accuracy: 0.3734 - loss: 1.6650 - val_accuracy: 0.3088 - val_loss: 1.6975 - learning_rate: 2.5000e-04
# Epoch 24/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3653 - loss: 1.6612
# Epoch 24: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 171s 2s/step - accuracy: 0.3644 - loss: 1.6521 - val_accuracy: 0.2788 - val_loss: 1.7876 - learning_rate: 2.5000e-04
# Epoch 25/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3852 - loss: 1.6362
# Epoch 25: val_accuracy did not improve from 0.48875
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Shrimp (63.1%) [Gilt-Head Bream: 13.1%, Hourse Mackerel: 14.3%, Sea Bass: 9.5%, Shrimp: 63.1%]
#   ✗ Shrimp (57.8%) [Gilt-Head Bream: 14.7%, Hourse Mackerel: 16.6%, Sea Bass: 11.0%, Shrimp: 57.8%]
#   ✗ Shrimp (56.4%) [Gilt-Head Bream: 15.1%, Hourse Mackerel: 17.2%, Sea Bass: 11.4%, Shrimp: 56.4%]
#   Class accuracy: 0/3 = 0.0%
#
# Hourse Mackerel:
#   ✗ Shrimp (59.6%) [Gilt-Head Bream: 14.6%, Hourse Mackerel: 15.3%, Sea Bass: 10.5%, Shrimp: 59.6%]
#   ✗ Shrimp (58.9%) [Gilt-Head Bream: 14.7%, Hourse Mackerel: 15.7%, Sea Bass: 10.7%, Shrimp: 58.9%]
#   ✗ Shrimp (59.6%) [Gilt-Head Bream: 14.6%, Hourse Mackerel: 15.3%, Sea Bass: 10.5%, Shrimp: 59.6%]
#   Class accuracy: 0/3 = 0.0%
#
# Sea Bass:
#   ✗ Shrimp (64.2%) [Gilt-Head Bream: 13.0%, Hourse Mackerel: 13.5%, Sea Bass: 9.2%, Shrimp: 64.2%]
#   ✗ Shrimp (61.1%) [Gilt-Head Bream: 14.0%, Hourse Mackerel: 14.8%, Sea Bass: 10.1%, Shrimp: 61.1%]
#   ✗ Shrimp (61.7%) [Gilt-Head Bream: 14.0%, Hourse Mackerel: 14.4%, Sea Bass: 10.0%, Shrimp: 61.7%]
#   Class accuracy: 0/3 = 0.0%
#
# Shrimp:
#   ✓ Shrimp (67.0%) [Gilt-Head Bream: 12.3%, Hourse Mackerel: 12.2%, Sea Bass: 8.5%, Shrimp: 67.0%]
#   ✓ Shrimp (67.0%) [Gilt-Head Bream: 12.4%, Hourse Mackerel: 12.1%, Sea Bass: 8.6%, Shrimp: 67.0%]
#   ✓ Shrimp (66.3%) [Gilt-Head Bream: 12.5%, Hourse Mackerel: 12.5%, Sea Bass: 8.6%, Shrimp: 66.3%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 3/12 = 25.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 210s 2s/step - accuracy: 0.3887 - loss: 1.6399 - val_accuracy: 0.2525 - val_loss: 1.8742 - learning_rate: 2.5000e-04
# Epoch 26/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3952 - loss: 1.6331
# Epoch 26: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 195s 2s/step - accuracy: 0.3897 - loss: 1.6294 - val_accuracy: 0.2688 - val_loss: 1.8221 - learning_rate: 2.5000e-04
# Epoch 27/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3725 - loss: 1.6387
# Epoch 27: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 194s 2s/step - accuracy: 0.3781 - loss: 1.6279 - val_accuracy: 0.2537 - val_loss: 1.6948 - learning_rate: 2.5000e-04
# Epoch 28/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.3825 - loss: 1.6037
# Epoch 28: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 172s 2s/step - accuracy: 0.3844 - loss: 1.6026 - val_accuracy: 0.3388 - val_loss: 1.5777 - learning_rate: 2.5000e-04
# Epoch 29/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 1s/step - accuracy: 0.3674 - loss: 1.6109
# Epoch 29: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 136s 1s/step - accuracy: 0.3747 - loss: 1.6024 - val_accuracy: 0.2637 - val_loss: 1.8551 - learning_rate: 2.5000e-04
# Epoch 30/30
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 869ms/step - accuracy: 0.3865 - loss: 1.5944
# Epoch 30: val_accuracy did not improve from 0.48875
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Shrimp (64.4%) [Gilt-Head Bream: 11.2%, Hourse Mackerel: 13.7%, Sea Bass: 10.7%, Shrimp: 64.4%]
#   ✗ Shrimp (55.7%) [Gilt-Head Bream: 13.7%, Hourse Mackerel: 17.3%, Sea Bass: 13.3%, Shrimp: 55.7%]
#   ✗ Shrimp (52.2%) [Gilt-Head Bream: 14.7%, Hourse Mackerel: 18.7%, Sea Bass: 14.3%, Shrimp: 52.2%]
#   Class accuracy: 0/3 = 0.0%
#
# Hourse Mackerel:
#   ✗ Shrimp (66.4%) [Gilt-Head Bream: 10.4%, Hourse Mackerel: 13.1%, Sea Bass: 10.1%, Shrimp: 66.4%]
#   ✗ Shrimp (64.5%) [Gilt-Head Bream: 10.9%, Hourse Mackerel: 13.9%, Sea Bass: 10.7%, Shrimp: 64.5%]
#   ✗ Shrimp (66.4%) [Gilt-Head Bream: 10.4%, Hourse Mackerel: 13.1%, Sea Bass: 10.1%, Shrimp: 66.4%]
#   Class accuracy: 0/3 = 0.0%
#
# Sea Bass:
#   ✗ Shrimp (71.6%) [Gilt-Head Bream: 8.9%, Hourse Mackerel: 10.9%, Sea Bass: 8.6%, Shrimp: 71.6%]
#   ✗ Shrimp (66.9%) [Gilt-Head Bream: 10.2%, Hourse Mackerel: 12.9%, Sea Bass: 10.0%, Shrimp: 66.9%]
#   ✗ Shrimp (69.1%) [Gilt-Head Bream: 9.6%, Hourse Mackerel: 12.0%, Sea Bass: 9.4%, Shrimp: 69.1%]
#   Class accuracy: 0/3 = 0.0%
#
# Shrimp:
#   ✓ Shrimp (75.9%) [Gilt-Head Bream: 7.6%, Hourse Mackerel: 9.1%, Sea Bass: 7.4%, Shrimp: 75.9%]
#   ✓ Shrimp (76.4%) [Gilt-Head Bream: 7.4%, Hourse Mackerel: 8.9%, Sea Bass: 7.3%, Shrimp: 76.4%]
#   ✓ Shrimp (75.8%) [Gilt-Head Bream: 7.6%, Hourse Mackerel: 9.2%, Sea Bass: 7.5%, Shrimp: 75.8%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 3/12 = 25.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 103s 1s/step - accuracy: 0.3828 - loss: 1.5918 - val_accuracy: 0.2725 - val_loss: 1.6886 - learning_rate: 2.5000e-04
# Restoring model weights from the end of the best epoch: 28.
#
# Phase 1 training complete!

# %%
# Test model with raw images after phase 1
labels = [name for name, _ in sorted(train_generator.class_indices.items(), key=lambda x: x[1])]
phase1_accuracy = test_model_with_raw_images(model, labels, num_per_class=5)

if phase1_accuracy < 0.5:
    print("\n⚠️ WARNING: Phase 1 accuracy is below 50%. The model is not learning properly.")
    print("Consider:")
    print("  1. Checking if dataset is corrupted")
    print("  2. Increasing EPOCHS to 50")
    print("  3. Trying a different random seed")
else:
    print(f"\n✓ Phase 1 successful! Raw image accuracy: {phase1_accuracy*100:.1f}%")
# Out:
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✗ Shrimp (53.7%) [Gilt-Head Bream: 15.6%, Hourse Mackerel: 17.6%, Sea Bass: 13.0%, Shrimp: 53.7%]
#   ✗ Shrimp (43.9%) [Gilt-Head Bream: 18.2%, Hourse Mackerel: 21.8%, Sea Bass: 16.1%, Shrimp: 43.9%]
#   ✗ Shrimp (38.6%) [Gilt-Head Bream: 19.8%, Hourse Mackerel: 23.8%, Sea Bass: 17.8%, Shrimp: 38.6%]
#   ✗ Shrimp (61.7%) [Gilt-Head Bream: 12.9%, Hourse Mackerel: 14.7%, Sea Bass: 10.7%, Shrimp: 61.7%]
#   ✗ Shrimp (61.7%) [Gilt-Head Bream: 12.8%, Hourse Mackerel: 14.8%, Sea Bass: 10.7%, Shrimp: 61.7%]
#   Class accuracy: 0/5 = 0.0%
#
# Hourse Mackerel:
#   ✗ Shrimp (60.8%) [Gilt-Head Bream: 13.1%, Hourse Mackerel: 15.1%, Sea Bass: 11.1%, Shrimp: 60.8%]
#   ✗ Shrimp (58.7%) [Gilt-Head Bream: 13.6%, Hourse Mackerel: 16.0%, Sea Bass: 11.7%, Shrimp: 58.7%]
#   ✗ Shrimp (60.8%) [Gilt-Head Bream: 13.1%, Hourse Mackerel: 15.1%, Sea Bass: 11.1%, Shrimp: 60.8%]
#   ✗ Shrimp (56.1%) [Gilt-Head Bream: 14.4%, Hourse Mackerel: 17.0%, Sea Bass: 12.5%, Shrimp: 56.1%]
#   ✗ Shrimp (65.1%) [Gilt-Head Bream: 11.8%, Hourse Mackerel: 13.2%, Sea Bass: 9.8%, Shrimp: 65.1%]
#   Class accuracy: 0/5 = 0.0%
#
# Sea Bass:
#   ✗ Shrimp (66.2%) [Gilt-Head Bream: 11.5%, Hourse Mackerel: 12.8%, Sea Bass: 9.4%, Shrimp: 66.2%]
#   ✗ Shrimp (61.1%) [Gilt-Head Bream: 13.0%, Hourse Mackerel: 15.0%, Sea Bass: 10.9%, Shrimp: 61.1%]
#   ✗ Shrimp (64.1%) [Gilt-Head Bream: 12.2%, Hourse Mackerel: 13.6%, Sea Bass: 10.1%, Shrimp: 64.1%]
#   ✗ Shrimp (59.9%) [Gilt-Head Bream: 13.4%, Hourse Mackerel: 15.4%, Sea Bass: 11.3%, Shrimp: 59.9%]
#   ✗ Shrimp (68.6%) [Gilt-Head Bream: 10.8%, Hourse Mackerel: 11.8%, Sea Bass: 8.8%, Shrimp: 68.6%]
#   Class accuracy: 0/5 = 0.0%
#
# Shrimp:
#   ✓ Shrimp (73.0%) [Gilt-Head Bream: 9.5%, Hourse Mackerel: 10.0%, Sea Bass: 7.6%, Shrimp: 73.0%]
#   ✓ Shrimp (73.7%) [Gilt-Head Bream: 9.2%, Hourse Mackerel: 9.6%, Sea Bass: 7.4%, Shrimp: 73.7%]
#   ✓ Shrimp (73.1%) [Gilt-Head Bream: 9.3%, Hourse Mackerel: 9.9%, Sea Bass: 7.6%, Shrimp: 73.1%]
#   ✓ Shrimp (73.7%) [Gilt-Head Bream: 9.2%, Hourse Mackerel: 9.6%, Sea Bass: 7.4%, Shrimp: 73.7%]
#   ✓ Shrimp (72.4%) [Gilt-Head Bream: 9.7%, Hourse Mackerel: 10.2%, Sea Bass: 7.7%, Shrimp: 72.4%]
#   Class accuracy: 5/5 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 5/20 = 25.0%
# ============================================================
#
#
# ⚠️ WARNING: Phase 1 accuracy is below 50%. The model is not learning properly.
# Consider:
#   1. Checking if dataset is corrupted
#   2. Increasing EPOCHS to 50
#   3. Trying a different random seed

# %%
# PHASE 2: Fine-tune the entire model
print("\n" + "="*60)
print("PHASE 2: Fine-tuning entire model")
print("="*60)

# Unfreeze the base model
base_model.trainable = True

# Recompile with lower learning rate
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=0.00005),
    loss=keras.losses.CategoricalCrossentropy(label_smoothing=0.1),
    metrics=['accuracy']
)

print(f"Fine-tuning with {len(model.trainable_variables)} trainable variables\n")

# Train with fine-tuning
history_finetune = model.fit(
    train_generator,
    epochs=FINETUNE_EPOCHS,
    validation_data=validation_generator,
    callbacks=callbacks,
    class_weight=class_weight_dict,
    verbose=1
)

print("\nPhase 2 fine-tuning complete!")
# Out:
# ============================================================
# PHASE 2: Fine-tuning entire model
# ============================================================
# Fine-tuning with 225 trainable variables
#
# Epoch 1/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.4148 - loss: 1.5731
# Epoch 1: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 374s 3s/step - accuracy: 0.5003 - loss: 1.4739 - val_accuracy: 0.2500 - val_loss: 5.6842 - learning_rate: 5.0000e-05
# Epoch 2/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.7274 - loss: 1.2589
# Epoch 2: val_accuracy did not improve from 0.48875
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 232s 2s/step - accuracy: 0.8031 - loss: 1.1862 - val_accuracy: 0.2450 - val_loss: 2.7223 - learning_rate: 5.0000e-05
# Epoch 3/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 3s/step - accuracy: 0.9171 - loss: 1.0029
# Epoch 3: val_accuracy improved from 0.48875 to 0.56000, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 3: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 337s 3s/step - accuracy: 0.9391 - loss: 0.9527 - val_accuracy: 0.5600 - val_loss: 1.4483 - learning_rate: 5.0000e-05
# Epoch 4/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9804 - loss: 0.8416
# Epoch 4: val_accuracy improved from 0.56000 to 0.97750, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 4: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 261s 3s/step - accuracy: 0.9797 - loss: 0.8193 - val_accuracy: 0.9775 - val_loss: 0.8015 - learning_rate: 5.0000e-05
# Epoch 5/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9875 - loss: 0.7599
# Epoch 5: val_accuracy improved from 0.97750 to 0.98000, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 5: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✓ Gilt-Head Bream (51.4%) [Gilt-Head Bream: 51.4%, Hourse Mackerel: 21.3%, Sea Bass: 12.1%, Shrimp: 15.2%]
#   ✗ Hourse Mackerel (36.4%) [Gilt-Head Bream: 26.5%, Hourse Mackerel: 36.4%, Sea Bass: 19.9%, Shrimp: 17.2%]
#   ✓ Gilt-Head Bream (46.2%) [Gilt-Head Bream: 46.2%, Hourse Mackerel: 22.8%, Sea Bass: 21.9%, Shrimp: 9.1%]
#   Class accuracy: 2/3 = 66.7%
#
# Hourse Mackerel:
#   ✓ Hourse Mackerel (75.1%) [Gilt-Head Bream: 8.2%, Hourse Mackerel: 75.1%, Sea Bass: 8.5%, Shrimp: 8.2%]
#   ✓ Hourse Mackerel (88.3%) [Gilt-Head Bream: 3.5%, Hourse Mackerel: 88.3%, Sea Bass: 4.1%, Shrimp: 4.1%]
#   ✓ Hourse Mackerel (74.5%) [Gilt-Head Bream: 8.5%, Hourse Mackerel: 74.5%, Sea Bass: 8.7%, Shrimp: 8.3%]
#   Class accuracy: 3/3 = 100.0%
#
# Sea Bass:
#   ✓ Sea Bass (60.8%) [Gilt-Head Bream: 10.5%, Hourse Mackerel: 17.7%, Sea Bass: 60.8%, Shrimp: 11.0%]
#   ✓ Sea Bass (70.9%) [Gilt-Head Bream: 7.5%, Hourse Mackerel: 12.2%, Sea Bass: 70.9%, Shrimp: 9.4%]
#   ✓ Sea Bass (38.2%) [Gilt-Head Bream: 10.1%, Hourse Mackerel: 26.5%, Sea Bass: 38.2%, Shrimp: 25.2%]
#   Class accuracy: 3/3 = 100.0%
#
# Shrimp:
#   ✓ Shrimp (58.3%) [Gilt-Head Bream: 8.3%, Hourse Mackerel: 18.3%, Sea Bass: 15.1%, Shrimp: 58.3%]
#   ✓ Shrimp (78.8%) [Gilt-Head Bream: 3.7%, Hourse Mackerel: 12.6%, Sea Bass: 4.9%, Shrimp: 78.8%]
#   ✓ Shrimp (66.5%) [Gilt-Head Bream: 7.9%, Hourse Mackerel: 13.2%, Sea Bass: 12.4%, Shrimp: 66.5%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 11/12 = 91.7%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 241s 2s/step - accuracy: 0.9891 - loss: 0.7489 - val_accuracy: 0.9800 - val_loss: 0.8050 - learning_rate: 5.0000e-05
# Epoch 6/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9917 - loss: 0.7194
# Epoch 6: val_accuracy did not improve from 0.98000
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 256s 3s/step - accuracy: 0.9912 - loss: 0.7174 - val_accuracy: 0.9750 - val_loss: 0.7566 - learning_rate: 5.0000e-05
# Epoch 7/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9929 - loss: 0.6982
# Epoch 7: val_accuracy improved from 0.98000 to 0.99250, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 7: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 243s 2s/step - accuracy: 0.9922 - loss: 0.6969 - val_accuracy: 0.9925 - val_loss: 0.6993 - learning_rate: 5.0000e-05
# Epoch 8/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9927 - loss: 0.6997
# Epoch 8: val_accuracy did not improve from 0.99250
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 233s 2s/step - accuracy: 0.9925 - loss: 0.6934 - val_accuracy: 0.9837 - val_loss: 0.7153 - learning_rate: 5.0000e-05
# Epoch 9/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9954 - loss: 0.6768
# Epoch 9: val_accuracy improved from 0.99250 to 1.00000, saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
#
# Epoch 9: finished saving model to C:\Users\s62ht\Downloads\fish_model_efficientnet/best_model.keras
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 257s 3s/step - accuracy: 0.9962 - loss: 0.6762 - val_accuracy: 1.0000 - val_loss: 0.6441 - learning_rate: 5.0000e-05
# Epoch 10/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9929 - loss: 0.6795
# Epoch 10: val_accuracy did not improve from 1.00000
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✓ Gilt-Head Bream (92.4%) [Gilt-Head Bream: 92.4%, Hourse Mackerel: 3.0%, Sea Bass: 2.9%, Shrimp: 1.7%]
#   ✓ Gilt-Head Bream (93.5%) [Gilt-Head Bream: 93.5%, Hourse Mackerel: 2.8%, Sea Bass: 2.3%, Shrimp: 1.4%]
#   ✓ Gilt-Head Bream (93.5%) [Gilt-Head Bream: 93.5%, Hourse Mackerel: 2.7%, Sea Bass: 2.3%, Shrimp: 1.5%]
#   Class accuracy: 3/3 = 100.0%
#
# Hourse Mackerel:
#   ✓ Hourse Mackerel (96.2%) [Gilt-Head Bream: 1.5%, Hourse Mackerel: 96.2%, Sea Bass: 1.1%, Shrimp: 1.2%]
#   ✓ Hourse Mackerel (95.3%) [Gilt-Head Bream: 1.9%, Hourse Mackerel: 95.3%, Sea Bass: 1.3%, Shrimp: 1.5%]
#   ✓ Hourse Mackerel (96.2%) [Gilt-Head Bream: 1.5%, Hourse Mackerel: 96.2%, Sea Bass: 1.1%, Shrimp: 1.2%]
#   Class accuracy: 3/3 = 100.0%
#
# Sea Bass:
#   ✓ Sea Bass (94.7%) [Gilt-Head Bream: 2.5%, Hourse Mackerel: 1.9%, Sea Bass: 94.7%, Shrimp: 1.0%]
#   ✓ Sea Bass (94.7%) [Gilt-Head Bream: 2.7%, Hourse Mackerel: 1.8%, Sea Bass: 94.7%, Shrimp: 0.8%]
#   ✓ Sea Bass (94.8%) [Gilt-Head Bream: 2.3%, Hourse Mackerel: 2.0%, Sea Bass: 94.8%, Shrimp: 0.9%]
#   Class accuracy: 3/3 = 100.0%
#
# Shrimp:
#   ✓ Shrimp (87.2%) [Gilt-Head Bream: 3.5%, Hourse Mackerel: 5.5%, Sea Bass: 3.8%, Shrimp: 87.2%]
#   ✓ Shrimp (87.5%) [Gilt-Head Bream: 3.5%, Hourse Mackerel: 4.7%, Sea Bass: 4.3%, Shrimp: 87.5%]
#   ✓ Shrimp (87.8%) [Gilt-Head Bream: 3.7%, Hourse Mackerel: 5.0%, Sea Bass: 3.5%, Shrimp: 87.8%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 12/12 = 100.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 250s 2s/step - accuracy: 0.9950 - loss: 0.6733 - val_accuracy: 0.9987 - val_loss: 0.6555 - learning_rate: 5.0000e-05
# Epoch 11/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9970 - loss: 0.6638
# Epoch 11: val_accuracy did not improve from 1.00000
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 246s 2s/step - accuracy: 0.9962 - loss: 0.6651 - val_accuracy: 1.0000 - val_loss: 0.6349 - learning_rate: 5.0000e-05
# Epoch 12/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9955 - loss: 0.6614
# Epoch 12: val_accuracy did not improve from 1.00000
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 245s 2s/step - accuracy: 0.9956 - loss: 0.6604 - val_accuracy: 1.0000 - val_loss: 0.6279 - learning_rate: 5.0000e-05
# Epoch 13/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9963 - loss: 0.6534
# Epoch 13: val_accuracy did not improve from 1.00000
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 244s 2s/step - accuracy: 0.9962 - loss: 0.6519 - val_accuracy: 0.9862 - val_loss: 0.6620 - learning_rate: 5.0000e-05
# Epoch 14/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9956 - loss: 0.6509
# Epoch 14: val_accuracy did not improve from 1.00000
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 234s 2s/step - accuracy: 0.9966 - loss: 0.6464 - val_accuracy: 0.9750 - val_loss: 0.7011 - learning_rate: 5.0000e-05
# Epoch 15/15
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 0s 2s/step - accuracy: 0.9964 - loss: 0.6410
# Epoch 15: val_accuracy did not improve from 1.00000
#
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✓ Gilt-Head Bream (95.9%) [Gilt-Head Bream: 95.9%, Hourse Mackerel: 1.7%, Sea Bass: 1.2%, Shrimp: 1.2%]
#   ✓ Gilt-Head Bream (96.7%) [Gilt-Head Bream: 96.7%, Hourse Mackerel: 1.5%, Sea Bass: 0.8%, Shrimp: 0.9%]
#   ✓ Gilt-Head Bream (97.3%) [Gilt-Head Bream: 97.3%, Hourse Mackerel: 1.2%, Sea Bass: 0.7%, Shrimp: 0.8%]
#   Class accuracy: 3/3 = 100.0%
#
# Hourse Mackerel:
#   ✓ Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   ✓ Hourse Mackerel (93.6%) [Gilt-Head Bream: 2.4%, Hourse Mackerel: 93.6%, Sea Bass: 2.1%, Shrimp: 1.9%]
#   ✓ Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   Class accuracy: 3/3 = 100.0%
#
# Sea Bass:
#   ✓ Sea Bass (91.3%) [Gilt-Head Bream: 4.0%, Hourse Mackerel: 3.0%, Sea Bass: 91.3%, Shrimp: 1.7%]
#   ✓ Sea Bass (89.4%) [Gilt-Head Bream: 5.9%, Hourse Mackerel: 3.2%, Sea Bass: 89.4%, Shrimp: 1.5%]
#   ✓ Sea Bass (91.3%) [Gilt-Head Bream: 3.3%, Hourse Mackerel: 3.6%, Sea Bass: 91.3%, Shrimp: 1.8%]
#   Class accuracy: 3/3 = 100.0%
#
# Shrimp:
#   ✓ Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   ✓ Shrimp (90.9%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.1%, Sea Bass: 3.1%, Shrimp: 90.9%]
#   ✓ Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   Class accuracy: 3/3 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 12/12 = 100.0%
# ============================================================
#
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 237s 2s/step - accuracy: 0.9972 - loss: 0.6387 - val_accuracy: 1.0000 - val_loss: 0.6146 - learning_rate: 5.0000e-05
# Restoring model weights from the end of the best epoch: 15.
#
# Phase 2 fine-tuning complete!

# %%
# Final evaluation
print("\nEvaluating final model...")
val_loss, val_accuracy = model.evaluate(validation_generator)
print(f"\nFinal Validation Loss: {val_loss:.4f}")
print(f"Final Validation Accuracy: {val_accuracy:.4f}")
# Out:
# Evaluating final model...
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 13s 528ms/step - accuracy: 1.0000 - loss: 0.6146
#
# Final Validation Loss: 0.6146
# Final Validation Accuracy: 1.0000

# %%
# Comprehensive test with raw images
final_accuracy = test_model_with_raw_images(model, labels, num_per_class=10)

if final_accuracy < 0.7:
    print("\n⚠️ WARNING: Final accuracy is below 70%.")
    print("The model may not work well in production.")
    print("\nRecommendations:")
    print("  1. Train for more epochs (try EPOCHS=50)")
    print("  2. Check dataset for mislabeled images")
    print("  3. Try different augmentation parameters")
else:
    print(f"\n✓ SUCCESS! Final raw image accuracy: {final_accuracy*100:.1f}%")
    print("Model is ready for deployment!")
# Out:
# ============================================================
# Testing model with raw images...
# ============================================================
#
# Gilt-Head Bream:
#   ✓ Gilt-Head Bream (95.9%) [Gilt-Head Bream: 95.9%, Hourse Mackerel: 1.7%, Sea Bass: 1.2%, Shrimp: 1.2%]
#   ✓ Gilt-Head Bream (96.7%) [Gilt-Head Bream: 96.7%, Hourse Mackerel: 1.5%, Sea Bass: 0.8%, Shrimp: 0.9%]
#   ✓ Gilt-Head Bream (97.3%) [Gilt-Head Bream: 97.3%, Hourse Mackerel: 1.2%, Sea Bass: 0.7%, Shrimp: 0.8%]
#   ✓ Gilt-Head Bream (91.2%) [Gilt-Head Bream: 91.2%, Hourse Mackerel: 3.2%, Sea Bass: 3.3%, Shrimp: 2.2%]
#   ✓ Gilt-Head Bream (95.5%) [Gilt-Head Bream: 95.5%, Hourse Mackerel: 1.9%, Sea Bass: 1.4%, Shrimp: 1.2%]
#   ✓ Gilt-Head Bream (95.2%) [Gilt-Head Bream: 95.2%, Hourse Mackerel: 2.0%, Sea Bass: 1.6%, Shrimp: 1.2%]
#   ✓ Gilt-Head Bream (96.8%) [Gilt-Head Bream: 96.8%, Hourse Mackerel: 1.3%, Sea Bass: 1.0%, Shrimp: 1.0%]
#   ✓ Gilt-Head Bream (96.9%) [Gilt-Head Bream: 96.9%, Hourse Mackerel: 1.2%, Sea Bass: 1.0%, Shrimp: 0.9%]
#   ✓ Gilt-Head Bream (97.4%) [Gilt-Head Bream: 97.4%, Hourse Mackerel: 1.0%, Sea Bass: 0.8%, Shrimp: 0.7%]
#   ✓ Gilt-Head Bream (97.5%) [Gilt-Head Bream: 97.5%, Hourse Mackerel: 1.0%, Sea Bass: 0.8%, Shrimp: 0.8%]
#   Class accuracy: 10/10 = 100.0%
#
# Hourse Mackerel:
#   ✓ Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   ✓ Hourse Mackerel (93.6%) [Gilt-Head Bream: 2.4%, Hourse Mackerel: 93.6%, Sea Bass: 2.1%, Shrimp: 1.9%]
#   ✓ Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   ✓ Hourse Mackerel (90.2%) [Gilt-Head Bream: 3.2%, Hourse Mackerel: 90.2%, Sea Bass: 3.8%, Shrimp: 2.8%]
#   ✓ Hourse Mackerel (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 92.5%, Sea Bass: 2.7%, Shrimp: 2.1%]
#   ✓ Hourse Mackerel (91.4%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 91.4%, Sea Bass: 3.4%, Shrimp: 2.4%]
#   ✓ Hourse Mackerel (91.9%) [Gilt-Head Bream: 3.0%, Hourse Mackerel: 91.9%, Sea Bass: 2.9%, Shrimp: 2.3%]
#   ✓ Hourse Mackerel (89.0%) [Gilt-Head Bream: 5.7%, Hourse Mackerel: 89.0%, Sea Bass: 2.5%, Shrimp: 2.8%]
#   ✓ Hourse Mackerel (93.8%) [Gilt-Head Bream: 2.4%, Hourse Mackerel: 93.8%, Sea Bass: 2.0%, Shrimp: 1.8%]
#   ✓ Hourse Mackerel (94.3%) [Gilt-Head Bream: 2.2%, Hourse Mackerel: 94.3%, Sea Bass: 1.9%, Shrimp: 1.7%]
#   Class accuracy: 10/10 = 100.0%
#
# Sea Bass:
#   ✓ Sea Bass (91.3%) [Gilt-Head Bream: 4.0%, Hourse Mackerel: 3.0%, Sea Bass: 91.3%, Shrimp: 1.7%]
#   ✓ Sea Bass (89.4%) [Gilt-Head Bream: 5.9%, Hourse Mackerel: 3.2%, Sea Bass: 89.4%, Shrimp: 1.5%]
#   ✓ Sea Bass (91.3%) [Gilt-Head Bream: 3.3%, Hourse Mackerel: 3.6%, Sea Bass: 91.3%, Shrimp: 1.8%]
#   ✓ Sea Bass (95.0%) [Gilt-Head Bream: 2.0%, Hourse Mackerel: 1.7%, Sea Bass: 95.0%, Shrimp: 1.3%]
#   ✓ Sea Bass (92.5%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.0%, Sea Bass: 92.5%, Shrimp: 1.6%]
#   ✓ Sea Bass (92.7%) [Gilt-Head Bream: 3.3%, Hourse Mackerel: 2.7%, Sea Bass: 92.7%, Shrimp: 1.3%]
#   ✓ Sea Bass (92.7%) [Gilt-Head Bream: 3.4%, Hourse Mackerel: 2.6%, Sea Bass: 92.7%, Shrimp: 1.3%]
#   ✓ Sea Bass (88.0%) [Gilt-Head Bream: 5.9%, Hourse Mackerel: 4.0%, Sea Bass: 88.0%, Shrimp: 2.1%]
#   ✓ Sea Bass (88.9%) [Gilt-Head Bream: 6.4%, Hourse Mackerel: 3.3%, Sea Bass: 88.9%, Shrimp: 1.3%]
#   ✓ Sea Bass (92.3%) [Gilt-Head Bream: 4.2%, Hourse Mackerel: 2.4%, Sea Bass: 92.3%, Shrimp: 1.1%]
#   Class accuracy: 10/10 = 100.0%
#
# Shrimp:
#   ✓ Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   ✓ Shrimp (90.9%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.1%, Sea Bass: 3.1%, Shrimp: 90.9%]
#   ✓ Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   ✓ Shrimp (91.1%) [Gilt-Head Bream: 2.7%, Hourse Mackerel: 3.1%, Sea Bass: 3.1%, Shrimp: 91.1%]
#   ✓ Shrimp (90.7%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.2%, Sea Bass: 3.2%, Shrimp: 90.7%]
#   ✓ Shrimp (91.9%) [Gilt-Head Bream: 2.7%, Hourse Mackerel: 3.0%, Sea Bass: 2.5%, Shrimp: 91.9%]
#   ✓ Shrimp (92.0%) [Gilt-Head Bream: 2.7%, Hourse Mackerel: 2.7%, Sea Bass: 2.6%, Shrimp: 92.0%]
#   ✓ Shrimp (91.7%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.0%, Sea Bass: 2.5%, Shrimp: 91.7%]
#   ✓ Shrimp (90.9%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.1%, Sea Bass: 3.0%, Shrimp: 90.9%]
#   ✓ Shrimp (94.3%) [Gilt-Head Bream: 2.0%, Hourse Mackerel: 1.9%, Sea Bass: 1.8%, Shrimp: 94.3%]
#   Class accuracy: 10/10 = 100.0%
#
# ============================================================
# OVERALL RAW IMAGE ACCURACY: 40/40 = 100.0%
# ============================================================
#
#
# ✓ SUCCESS! Final raw image accuracy: 100.0%
# Model is ready for deployment!

# %%
# Save model in Keras format
keras_model_path = f'{WORK_DIR}/fish_model_efficientnet.keras'
model.save(keras_model_path)
print(f"Keras model saved to: {keras_model_path}")
# Out:
# Keras model saved to: C:\Users\s62ht\Downloads\fish_model_efficientnet/fish_model_efficientnet.keras

# %%
# Convert to TensorFlow Lite WITHOUT quantization
print("\nConverting to TensorFlow Lite (full precision)...")

converter = tf.lite.TFLiteConverter.from_keras_model(model)
# NO quantization - keeps full float32 precision
tflite_model = converter.convert()

# Save TFLite model
tflite_path = f'{WORK_DIR}/fish_classifier.tflite'
with open(tflite_path, 'wb') as f:
    f.write(tflite_model)

file_size = os.path.getsize(tflite_path) / (1024 * 1024)
print(f"\nTFLite model saved: fish_classifier.tflite")
print(f"Size: {file_size:.2f} MB")
# Out:
# Converting to TensorFlow Lite (full precision)...
# INFO:tensorflow:Assets written to: C:\Users\s62ht\AppData\Local\Temp\tmpqqtw7fmq\assets
# INFO:tensorflow:Assets written to: C:\Users\s62ht\AppData\Local\Temp\tmpqqtw7fmq\assets
# Saved artifact at 'C:\Users\s62ht\AppData\Local\Temp\tmpqqtw7fmq'. The following endpoints are available:
#
# * Endpoint 'serve'
#   args_0 (POSITIONAL_ONLY): TensorSpec(shape=(None, 224, 224, 3), dtype=tf.float32, name='keras_tensor_238')
# Output Type:
#   TensorSpec(shape=(None, 4), dtype=tf.float32, name=None)
# Captures:
#   2198583462608: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2198583462416: TensorSpec(shape=(1, 1, 1, 3), dtype=tf.float32, name=None)
#   2198551940560: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551941712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551941328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551938832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551941520: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551940944: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551940752: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551941136: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551942096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551940176: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551940368: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551943248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551942480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551943632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551944208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551944016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551944976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551945360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551943824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551945936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551946128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551945552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551946896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551946320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551947280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551947664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551947472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551948432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551947856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551946704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551948624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551946512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551948816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551948048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551950160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551950352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551951120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551950544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551949968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551948240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551950928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551951504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551950736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551952272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551953232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551952464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551953040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551952656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551951696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557229328: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551952848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551951312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557230096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557230480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557230288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557231248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557230672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557230864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557231632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557231440: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557231824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557229904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557233360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557233744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557231056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557234128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557233168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557233552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557234320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557235088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557234512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557233936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557235280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557234704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557236048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557235472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557234896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557236240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557232208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557236432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557235664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557236816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557236624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557238160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557238928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557238352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557239120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557238544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557239888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557239312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557238736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557240848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557240080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557241232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557237584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557240272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557239504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557241616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557240656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557241040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557241808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557240464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557241424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557243536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557242384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557244496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557243728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557244880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557239696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557243920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557243152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557245264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557244304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557244112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558277712: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558278096: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557245072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198557244688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558278480: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558278864: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558278672: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558279632: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558279056: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558277904: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280592: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558279824: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280976: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558278288: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280016: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558279248: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558281360: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280400: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280208: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558281744: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558281552: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558282512: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558281936: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558280784: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558282704: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558282128: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558283472: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558282896: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558282320: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558284432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558283664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558284816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558281168: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558283856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558283088: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558284240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558284624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558284048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558286160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558286352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558287120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558286544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558285968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558288080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558287312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558288464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558283280: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558287504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558286736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558288848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558287888: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558287696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558289232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558289040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558290000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558289424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558288272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558290192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558289616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558290960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558290384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558289808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558291920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558291152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558292304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558288656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558291344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558290576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558292688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558291728: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558291536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558293072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558292880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558293840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558293264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558292112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558292496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575939664: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558293456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198558293648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575940240: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941392: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575940624: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941776: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575940048: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575940816: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575940432: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575942160: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941200: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941584: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575942352: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941008: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575943120: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575942544: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575941968: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575943312: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575942736: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575944080: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575943504: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575942928: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575945040: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575944272: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575945424: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575939856: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575944464: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575943696: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575945808: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575944848: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575944656: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946192: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946000: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946960: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946384: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575945232: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575947152: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946576: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575947920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575947344: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575946768: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575948880: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575948112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575949264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575945616: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575948304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575947536: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575949648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575948688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575948496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950032: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575949840: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950800: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575949072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950416: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575951760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575951184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575950608: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575952720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575951952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575953104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575949456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575952144: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575951376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575953488: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575952528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575952336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575953872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575953680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575954640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575954064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575952912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575954832: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575954256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575955600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575955024: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575954448: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575955792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575955408: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575953296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198575955216: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583460496: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583460688: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583459920: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583460304: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583461072: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583461456: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583461264: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583462224: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583461648: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551939792: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198551939984: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583463184: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583462992: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583460112: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583463376: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583463952: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583464912: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583464528: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583464336: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583463760: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583464720: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583465296: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583466256: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583465872: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583465680: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583465104: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583466064: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583466640: TensorSpec(shape=(), dtype=tf.resource, name=None)
#   2198583467600: TensorSpec(shape=(), dtype=tf.resource, name=None)
#
# TFLite model saved: fish_classifier.tflite
# Size: 18.42 MB

# %%
# Generate labels.txt file
class_indices = train_generator.class_indices
sorted_classes = sorted(class_indices.items(), key=lambda x: x[1])
labels = [class_name for class_name, _ in sorted_classes]

labels_path = f'{WORK_DIR}/labels.txt'
with open(labels_path, 'w') as f:
    for label in labels:
        f.write(f"{label}\n")

print("\nLabels file created: labels.txt")
print("Contents:")
for i, label in enumerate(labels):
    print(f"  {i}: {label}")
# Out:
# Labels file created: labels.txt
# Contents:
#   0: Gilt-Head Bream
#   1: Hourse Mackerel
#   2: Sea Bass
#   3: Shrimp

# %%
# Final test of TFLite model
print("\n" + "="*60)
print("FINAL TFLITE MODEL TEST")
print("="*60)

def preprocess_image_flutter_style(image_path):
    """Preprocess image exactly as Flutter does"""
    img = Image.open(image_path).convert('RGB')
    
    # Center crop to square
    width, height = img.size
    size = min(width, height)
    left = (width - size) // 2
    top = (height - size) // 2
    img = img.crop((left, top, left + size, top + size))
    
    # Resize to 224x224
    img = img.resize((224, 224), Image.BILINEAR)
    
    # Normalize: (pixel / 127.5) - 1.0
    img_array = np.array(img, dtype=np.float32)
    img_array = (img_array / 127.5) - 1.0
    img_array = np.expand_dims(img_array, axis=0)
    
    return img_array

# Load TFLite interpreter
interpreter = tf.lite.Interpreter(model_path=tflite_path)
interpreter.allocate_tensors()

input_details = interpreter.get_input_details()
output_details = interpreter.get_output_details()

print(f"Input shape: {input_details[0]['shape']}")
print(f"Output shape: {output_details[0]['shape']}")
print()

# Test 5 images from each class
total_correct = 0
total_tested = 0

for class_name in labels:
    class_dir = os.path.join(VAL_DIR, class_name)
    if not os.path.exists(class_dir):
        continue
    
    images = [f for f in os.listdir(class_dir) if f.lower().endswith(('.png', '.jpg', '.jpeg'))][:5]
    
    print(f"Testing {class_name}:")
    class_correct = 0
    
    for img_name in images:
        img_path = os.path.join(class_dir, img_name)
        input_data = preprocess_image_flutter_style(img_path)
        
        # Run TFLite inference
        interpreter.set_tensor(input_details[0]['index'], input_data)
        interpreter.invoke()
        output = interpreter.get_tensor(output_details[0]['index'])[0]
        
        predicted_idx = np.argmax(output)
        predicted_label = labels[predicted_idx]
        confidence = output[predicted_idx]
        
        is_correct = predicted_label == class_name
        status = "✓" if is_correct else "✗"
        
        probs_str = ", ".join([f"{labels[i]}: {output[i]*100:.1f}%" for i in range(len(labels))])
        print(f"  {status} {img_name}: {predicted_label} ({confidence*100:.1f}%) [{probs_str}]")
        
        if is_correct:
            class_correct += 1
            total_correct += 1
        total_tested += 1
    
    print(f"  Class accuracy: {class_correct}/{len(images)} = {class_correct/len(images)*100:.1f}%")
    print()

tflite_accuracy = total_correct / total_tested if total_tested > 0 else 0
print("="*60)
print(f"TFLITE OVERALL ACCURACY: {total_correct}/{total_tested} = {tflite_accuracy*100:.1f}%")
print("="*60)
# Out:
# ============================================================
# FINAL TFLITE MODEL TEST
# ============================================================
# Input shape: [  1 224 224   3]
# Output shape: [1 4]
#
# Testing Gilt-Head Bream:
#   ✓ 00004.png: Gilt-Head Bream (95.9%) [Gilt-Head Bream: 95.9%, Hourse Mackerel: 1.7%, Sea Bass: 1.2%, Shrimp: 1.2%]
# C:\Users\s62ht\AppData\Roaming\Python\Python313\site-packages\tensorflow\lite\python\interpreter.py:457: UserWarning:     Warning: tf.lite.Interpreter is deprecated and is scheduled for deletion in
#     TF 2.20. Please use the LiteRT interpreter from the ai_edge_litert package.
#     See the [migration guide](https://ai.google.dev/edge/litert/migration)
#     for details.
#
#   warnings.warn(_INTERPRETER_DELETION_WARNING)
#   ✓ 00007.png: Gilt-Head Bream (96.7%) [Gilt-Head Bream: 96.7%, Hourse Mackerel: 1.5%, Sea Bass: 0.8%, Shrimp: 0.9%]
#   ✓ 00012.png: Gilt-Head Bream (97.3%) [Gilt-Head Bream: 97.3%, Hourse Mackerel: 1.2%, Sea Bass: 0.7%, Shrimp: 0.8%]
#   ✓ 00026.png: Gilt-Head Bream (91.2%) [Gilt-Head Bream: 91.2%, Hourse Mackerel: 3.2%, Sea Bass: 3.3%, Shrimp: 2.2%]
#   ✓ 00028.png: Gilt-Head Bream (95.5%) [Gilt-Head Bream: 95.5%, Hourse Mackerel: 1.9%, Sea Bass: 1.4%, Shrimp: 1.2%]
#   Class accuracy: 5/5 = 100.0%
#
# Testing Hourse Mackerel:
#   ✓ 00004.png: Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   ✓ 00007.png: Hourse Mackerel (93.6%) [Gilt-Head Bream: 2.4%, Hourse Mackerel: 93.6%, Sea Bass: 2.1%, Shrimp: 1.9%]
#   ✓ 00012.png: Hourse Mackerel (91.1%) [Gilt-Head Bream: 4.1%, Hourse Mackerel: 91.1%, Sea Bass: 2.4%, Shrimp: 2.4%]
#   ✓ 00026.png: Hourse Mackerel (90.2%) [Gilt-Head Bream: 3.2%, Hourse Mackerel: 90.2%, Sea Bass: 3.8%, Shrimp: 2.8%]
#   ✓ 00028.png: Hourse Mackerel (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 92.5%, Sea Bass: 2.7%, Shrimp: 2.1%]
#   Class accuracy: 5/5 = 100.0%
#
# Testing Sea Bass:
#   ✓ 00004.png: Sea Bass (91.3%) [Gilt-Head Bream: 4.0%, Hourse Mackerel: 3.0%, Sea Bass: 91.3%, Shrimp: 1.7%]
#   ✓ 00007.png: Sea Bass (89.4%) [Gilt-Head Bream: 5.9%, Hourse Mackerel: 3.2%, Sea Bass: 89.4%, Shrimp: 1.5%]
#   ✓ 00012.png: Sea Bass (91.3%) [Gilt-Head Bream: 3.3%, Hourse Mackerel: 3.6%, Sea Bass: 91.3%, Shrimp: 1.8%]
#   ✓ 00026.png: Sea Bass (95.0%) [Gilt-Head Bream: 2.0%, Hourse Mackerel: 1.7%, Sea Bass: 95.0%, Shrimp: 1.3%]
#   ✓ 00028.png: Sea Bass (92.5%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.0%, Sea Bass: 92.5%, Shrimp: 1.6%]
#   Class accuracy: 5/5 = 100.0%
#
# Testing Shrimp:
#   ✓ 00004.png: Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   ✓ 00007.png: Shrimp (90.9%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.1%, Sea Bass: 3.1%, Shrimp: 90.9%]
#   ✓ 00012.png: Shrimp (92.5%) [Gilt-Head Bream: 2.6%, Hourse Mackerel: 2.5%, Sea Bass: 2.4%, Shrimp: 92.5%]
#   ✓ 00026.png: Shrimp (91.1%) [Gilt-Head Bream: 2.7%, Hourse Mackerel: 3.1%, Sea Bass: 3.1%, Shrimp: 91.1%]
#   ✓ 00028.png: Shrimp (90.7%) [Gilt-Head Bream: 2.9%, Hourse Mackerel: 3.2%, Sea Bass: 3.2%, Shrimp: 90.7%]
#   Class accuracy: 5/5 = 100.0%
#
# ============================================================
# TFLITE OVERALL ACCURACY: 20/20 = 100.0%
# ============================================================

# %%
# Final summary
print("\n" + "="*60)
print("TRAINING COMPLETE")
print("="*60)
print(f"\nFiles created in: {WORK_DIR}")
print("  1. fish_classifier.tflite - Full precision model")
print("  2. labels.txt - Class labels")
print("  3. fish_model_efficientnet.keras - Keras model")
print("\nModel Performance:")
print(f"  Validation Accuracy: {val_accuracy:.2%}")
print(f"  Raw Image Accuracy: {final_accuracy:.2%}")
print(f"  TFLite Accuracy: {tflite_accuracy:.2%}")
print(f"  Model Size: {file_size:.2f} MB")

if tflite_accuracy >= 0.7:
    print("\n✅ SUCCESS! Model is ready for Flutter.")
    print("\nNext Steps:")
    print(f"  1. Copy {WORK_DIR}\\fish_classifier.tflite")
    print(f"     to c:\\Users\\s62ht\\Desktop\\Bahaar\\assets\\models\\")
    print(f"  2. Copy {WORK_DIR}\\labels.txt")
    print(f"     to c:\\Users\\s62ht\\Desktop\\Bahaar\\assets\\models\\")
    print("  3. Test in Flutter app")
else:
    print("\n❌ WARNING: Model accuracy is too low.")
    print("\nTroubleshooting:")
    print("  1. Increase EPOCHS to 50")
    print("  2. Check dataset for issues")
    print("  3. Try running training again with different random seed")

print("\n" + "="*60)
# Out:
# ============================================================
# TRAINING COMPLETE
# ============================================================
#
# Files created in: C:\Users\s62ht\Downloads\fish_model_efficientnet
#   1. fish_classifier.tflite - Full precision model
#   2. labels.txt - Class labels
#   3. fish_model_efficientnet.keras - Keras model
#
# Model Performance:
#   Validation Accuracy: 100.00%
#   Raw Image Accuracy: 100.00%
#   TFLite Accuracy: 100.00%
#   Model Size: 18.42 MB
#
# ✅ SUCCESS! Model is ready for Flutter.
#
# Next Steps:
#   1. Copy C:\Users\s62ht\Downloads\fish_model_efficientnet\fish_classifier.tflite
#      to c:\Users\s62ht\Desktop\Bahaar\assets\models\
#   2. Copy C:\Users\s62ht\Downloads\fish_model_efficientnet\labels.txt
#      to c:\Users\s62ht\Desktop\Bahaar\assets\models\
#   3. Test in Flutter app
#
# ============================================================
